# %% [markdown]
# # EDA:

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Config

# %%
pd.read_csv('../')

# %% [markdown]
# ## Constants

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Read Data

# %%
## EDA

# %%
#
